# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('../data/Direct-catches-summary-data-since-1985-V7_2-2025.csv', sep=';')

# Group by year and sum the total catches
yearly_totals = df.groupby('Year')['Total'].sum().reset_index()

# Create the plot
plt.figure(figsize=(12, 6))
plt.bar(yearly_totals['Year'], yearly_totals['Total'], color='skyblue')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Total Whale Catches')
plt.title('Total Whale Catches by Year (1985-2024)')
plt.xticks(rotation=45)
# Out:
# (array([1980., 1985., 1990., 1995., 2000., 2005., 2010., 2015., 2020.,
#         2025., 2030.]),
#  [Text(1980.0, 0, '1980'),
#   Text(1985.0, 0, '1985'),
#   Text(1990.0, 0, '1990'),
#   Text(1995.0, 0, '1995'),
#   Text(2000.0, 0, '2000'),
#   Text(2005.0, 0, '2005'),
#   Text(2010.0, 0, '2010'),
#   Text(2015.0, 0, '2015'),
#   Text(2020.0, 0, '2020'),
#   Text(2025.0, 0, '2025'),
#   Text(2030.0, 0, '2030')])
