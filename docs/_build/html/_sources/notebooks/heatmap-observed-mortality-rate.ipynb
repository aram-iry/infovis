# %%
import pandas as pd
import plotly.graph_objects as go

# Load the data
df = pd.read_csv('table5_whale-only_bycatch_data.csv')

# Get unique years and sort them
years = df['Calendar Year'].unique()
years.sort()

# Create traces for each year
traces = []
for year in years:
    year_df = df[df['Calendar Year'] == year]
    trace = go.Densitymapbox(
        lat=year_df['LATITUDE (5° cell)'],
        lon=year_df['LONGITUDE (5° cell)'],
        z=year_df['Observed Mortality rate (per set)'],
        radius=10,
        visible=(year == years[0]),  # Only first year visible initially
        colorbar=dict(
            title='Mortality Rate per Set',
            titleside='right'
        ),
        hovertext=year_df['Species (or group)'],
        hovertemplate='<b>Species:</b> %{hovertext}<br>' +
                      '<b>Lat:</b> %{lat:.1f}°<br>' +
                      '<b>Lon:</b> %{lon:.1f}°<br>' +
                      '<b>Mortality Rate:</b> %{z:.6f}<extra></extra>'
    )
    traces.append(trace)

# Create slider steps
slider_steps = []
for i, year in enumerate(years):
    slider_steps.append({
        'method': 'update',
        'args': [
            {'visible': [i == j for j in range(len(traces))]},
            {'title': 'Whale Bycatch Mortality Rate Heatmap'}
        ],
        'label': str(year)
    })

# Create the figure
fig = go.Figure(
    data=traces,
    layout=go.Layout(
        title='Whale Bycatch Mortality Rate Heatmap',
        mapbox=dict(
            accesstoken='pk.eyJ1IjoicnRob21hc2oiLCJhIjoiY21iejRtNzlnMWtndTJqczFvMXpramZrNiJ9.jsM767FfF1Z0GB1v_ns-qQ',
            style='carto-positron',
            center=dict(lat=0, lon=180),
            zoom=2
        ),
        sliders=[{
            'active': 0,
            'currentvalue': {'prefix': 'Year: '},
            'steps': slider_steps
        }],
        margin={'t': 50, 'r': 20, 'b': 20, 'l': 20}
    )
)

# Update layout for better visualization
fig.update_layout(
    width=1000,
    height=700,
    mapbox_style="carto-positron",
    mapbox_center_lon=180
)

# Add caption above the slider
fig.add_annotation(
    x=0.5, y=-0.1,
    xref='paper', yref='paper',
    xanchor='center',
    yanchor='top',
    text='Drag the slider to view mortality rates by year',
    showarrow=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2fcef417-7f1a-4583-9b31-ecfdf70dbdc2" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fcef417-7f1a-4583-9b31-ecfdf70dbdc2")) {                    Plotly.newPlot(                        "2fcef417-7f1a-4583-9b31-ecfdf70dbdc2",                        [{"colorbar":{"title":{"side":"right","text":"Mortality Rate per Set"}},"hovertemplate":"\u003cb\u003eSpecies:\u003c\u002fb\u003e %{hovertext}\u003cbr\u003e\u003cb\u003eLat:\u003c\u002fb\u003e %{lat:.1f}°\u003cbr\u003e\u003cb\u003eLon:\u003c\u002fb\u003e %{lon:.1f}°\u003cbr\u003e\u003cb\u003eMortality Rate:\u003c\u002fb\u003e %{z:.6f}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BALEEN WHALES NEI","BALEEN WHALES NEI","BALEEN WHALES NEI","BALEEN WHALES NEI","BALEEN WHALES NEI","BALEEN WHALES NEI","BALEEN WHALES NEI","BALEEN WHALES NEI","BALEEN WHALES NEI","BEAKED WHALES NEI","BEAKED WHALES NEI","BLAINVILLE'S BEAKED WHALE","BLAINVILLE'S BEAKED WHALE","BLUE WHALE","BLUE WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","BRYDE'S WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","FALSE KILLER WHALE","GINKGO-TOOTHED BEAKED WHALE","GINKGO-TOOTHED BEAKED WHALE","GINKGO-TOOTHED BEAKED WHALE","GINKGO-TOOTHED BEAKED WHALE","HUMPBACK WHALE","HUMPBACK WHALE","HUMPBACK WHALE","HUMPBACK WHALE","HUMPBACK WHALE","KILLER WHALE","MELON-HEADED WHALE","MELON-HEADED WHALE","MELON-HEADED WHALE","MELON-HEADED WHALE","MINKE WHALE","MINKE WHALE","NORTHERN RIGHT WHALE DOLPHIN","PYGMY KILLER WHALE","PYGMY KILLER WHALE","PYGMY KILLER WHALE","PYGMY KILLER WHALE","PYGMY KILLER WHALE","PYGMY KILLER WHALE","PYGMY KILLER WHALE","PYGMY KILLER WHALE","PYGMY SPERM WHALE","PYGMY SPERM WHALE","PYGMY SPERM WHALE","PYGMY SPERM WHALE","PYGMY SPERM WHALE","SEI WHALE","SEI WHALE","SEI WHALE","SEI WHALE","SEI WHALE","SEI WHALE","SEI WHALE","SEI WHALE","SEI WHALE","SEI WHALE","SEI WHALE","SEI WHALE","SEI WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SHORT-FINNED PILOT WHALE","SPERM WHALE","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK","WHALE SHARK"],"lat":[-7.5,-7.5,-7.5,-2.5,-2.5,-2.5,-2.5,-2.5,2.5,-2.5,-2.5,-2.5,-2.5,-7.5,2.5,-12.5,-7.5,-7.5,-2.5,-2.5,-2.5,-2.5,-2.5,-2.5,-2.5,2.5,2.5,2.5,2.5,-7.5,-7.5,-7.5,-2.5,-2.5,-2.5,-2.5,-2.5,-2.5,-2.5,-2.5,-2.5,-2.5,-2.5,2.5,2.5,2.5,2.5,2.5,2.5,2.5,7.5,-7. ...
